# %%
import pandas as pd
from sqlalchemy import create_engine
import numpy as np
import requests
import json
import prettytable
import xmltodict, json
from pandas.io.json import json_normalize
from Password import password, username

# %% [markdown]
# ## Store CSV into DataFrame

# %%
data_file = "Resources/2015.xlsx"
data2015_df = pd.read_excel(data_file)
data2015_df.head()
# Out:
#    Year Qtr Area Type     St Name                         Area  \
# 0  2015   A    County  New Jersey  Atlantic County, New Jersey
# 1  2015   A    County  New Jersey  Atlantic County, New Jersey
# 2  2015   A    County  New Jersey  Atlantic County, New Jersey
# 3  2015   A    County  New Jersey  Atlantic County, New Jersey
# 4  2015   A    County  New Jersey  Atlantic County, New Jersey
#
#             Ownership               Industry Annual Average Status Code  \
# 0       Total Covered  Total, all industries                        NaN
# 1  Federal Government  Total, all industries                        NaN
# 2    State Government  Total, all industries                        NaN
# 3    Local Government  Total, all industries                        NaN
# 4             Private  Total, all industries                        NaN
#
#    Annual Average Establishment Count  Annual Average Employment  \
# 0                                6403                     124905
# ...

# %%
data_file = "Resources/2016.xlsx"
data2016_df = pd.read_excel(data_file)
data2016_df.head()
# Out:
#    Year Qtr Area Type     St Name                         Area  \
# 0  2016   A    County  New Jersey  Atlantic County, New Jersey
# 1  2016   A    County  New Jersey  Atlantic County, New Jersey
# 2  2016   A    County  New Jersey  Atlantic County, New Jersey
# 3  2016   A    County  New Jersey  Atlantic County, New Jersey
# 4  2016   A    County  New Jersey  Atlantic County, New Jersey
#
#             Ownership               Industry Annual Average Status Code  \
# 0       Total Covered  Total, all industries                        NaN
# 1  Federal Government  Total, all industries                        NaN
# 2    State Government  Total, all industries                        NaN
# 3    Local Government  Total, all industries                        NaN
# 4             Private  Total, all industries                        NaN
#
#    Annual Average Establishment Count  Annual Average Employment  \
# 0                                6455                     124840
# ...

# %%
data_file = "Resources/2017.xlsx"
data2017_df = pd.read_excel(data_file)
data2017_df.head()
# Out:
#    Year Qtr Area Type     St Name                         Area  \
# 0  2017   A    County  New Jersey  Atlantic County, New Jersey
# 1  2017   A    County  New Jersey  Atlantic County, New Jersey
# 2  2017   A    County  New Jersey  Atlantic County, New Jersey
# 3  2017   A    County  New Jersey  Atlantic County, New Jersey
# 4  2017   A    County  New Jersey  Atlantic County, New Jersey
#
#             Ownership                  Industry Annual Average Status Code  \
# 0       Total Covered  10 Total, all industries                        NaN
# 1  Federal Government  10 Total, all industries                        NaN
# 2    State Government  10 Total, all industries                        NaN
# 3    Local Government  10 Total, all industries                        NaN
# 4             Private  10 Total, all industries                        NaN
#
#    Annual Average Establishment Count  Annual Average Employment  \
# 0                                6474                     123400
# ...

# %%
data_file = "Resources/2018.xlsx"
data2018_df = pd.read_excel(data_file)
data2018_df.head()
# Out:
#    Year Qtr Area Type     St Name                         Area  \
# 0  2018   A    County  New Jersey  Atlantic County, New Jersey
# 1  2018   A    County  New Jersey  Atlantic County, New Jersey
# 2  2018   A    County  New Jersey  Atlantic County, New Jersey
# 3  2018   A    County  New Jersey  Atlantic County, New Jersey
# 4  2018   A    County  New Jersey  Atlantic County, New Jersey
#
#             Ownership                  Industry Annual Average Status Code  \
# 0       Total Covered  10 Total, all industries                        NaN
# 1  Federal Government  10 Total, all industries                        NaN
# 2    State Government  10 Total, all industries                        NaN
# 3    Local Government  10 Total, all industries                        NaN
# 4             Private  10 Total, all industries                        NaN
#
#    Annual Average Establishment Count  Annual Average Employment  \
# 0                                6485                     126911
# ...

# %% [markdown]
# ## Merge the files

# %%
frames = [data2015_df,data2016_df,data2017_df,data2018_df]
result = pd.concat(frames)
result
# Out:
#      Year Qtr Area Type     St Name                              Area  \
# 0    2015   A    County  New Jersey       Atlantic County, New Jersey
# 1    2015   A    County  New Jersey       Atlantic County, New Jersey
# 2    2015   A    County  New Jersey       Atlantic County, New Jersey
# 3    2015   A    County  New Jersey       Atlantic County, New Jersey
# 4    2015   A    County  New Jersey       Atlantic County, New Jersey
# ..    ...  ..       ...         ...                               ...
# 391  2018   A    County  New Jersey  Unknown Or Undefined, New Jersey
# 392  2018   A    County  New Jersey  Unknown Or Undefined, New Jersey
# 393  2018   A    County  New Jersey  Unknown Or Undefined, New Jersey
# 394  2018   A    County  New Jersey  Unknown Or Undefined, New Jersey
# 395  2018   A    County  New Jersey  Unknown Or Undefined, New Jersey
#
#               Ownership                                 Industry  \
# ...

# %% [markdown]
# ## Create new data with select columns

# %%
new_data_df = result[['Year', 'Area','Industry','Annual Average Establishment Count','Annual Average Employment','Annual Total Wages','Annual Average Weekly Wage','Annual Average Pay']].copy()
new_data_df.head()
# Out:
#    Year                         Area               Industry  \
# 0  2015  Atlantic County, New Jersey  Total, all industries
# 1  2015  Atlantic County, New Jersey  Total, all industries
# 2  2015  Atlantic County, New Jersey  Total, all industries
# 3  2015  Atlantic County, New Jersey  Total, all industries
# 4  2015  Atlantic County, New Jersey  Total, all industries
#
#    Annual Average Establishment Count  Annual Average Employment  \
# 0                                6403                     124905
# 1                                  53                       2580
# 2                                  57                       3556
# 3                                 131                      14773
# 4                                6162                     103996
#
#    Annual Total Wages  Annual Average Weekly Wage  Annual Average Pay
# 0          5459761042                         841               43711
# 1           245039710                        1827               94989
# ...

# %%
new_data_df[['county','state']] = new_data_df['Area'].str.split(',',expand=True)
new_data_df.head()
# Out:
#    Year                         Area               Industry  \
# 0  2015  Atlantic County, New Jersey  Total, all industries
# 1  2015  Atlantic County, New Jersey  Total, all industries
# 2  2015  Atlantic County, New Jersey  Total, all industries
# 3  2015  Atlantic County, New Jersey  Total, all industries
# 4  2015  Atlantic County, New Jersey  Total, all industries
#
#    Annual Average Establishment Count  Annual Average Employment  \
# 0                                6403                     124905
# 1                                  53                       2580
# 2                                  57                       3556
# 3                                 131                      14773
# 4                                6162                     103996
#
#    Annual Total Wages  Annual Average Weekly Wage  Annual Average Pay  \
# 0          5459761042                         841               43711
# ...

# %% [markdown]
# ## BLS API

# %%
## Full Table
headers = {'Content-type': 'application/json'}

data = json.dumps({"seriesid": ['LNS11000000'],"startyear":"2015", "endyear":"2019"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
        #if 'M01' <= period <= 'M12':'
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(seriesId + '.txt','w')
    output.write (x.get_string())
    output.close()
json_data
# Out:
# {'status': 'REQUEST_SUCCEEDED',
#  'responseTime': 181,
#  'message': [],
#  'Results': {'series': [{'seriesID': 'LNS11000000',
#     'data': [{'year': '2019',
#       'period': 'M12',
#       'periodName': 'December',
#       'value': '164556',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M11',
#       'periodName': 'November',
#       'value': '164347',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M10',
#       'periodName': 'October',
#       'value': '164401',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M09',
#       'periodName': 'September',
#       'value': '164051',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M08',
#       'periodName': 'August',
#       'value': '163894',
#       'footnotes': [{}]},
#      {'year': '2019',
#       'period': 'M07',
#       'periodName': 'July',
#       'value': '163373',
#       'footnotes': [{}]},
#      {'year': '2019',
# ...

# %%
# Employment


headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": [' LNS12000000'],"startyear":"2015", "endyear":"2019"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
        #if 'M01' <= period <= 'M12':'
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(seriesId + '.txt','w')
    output.write (x.get_string())
    output.close()
json_data
# Out:
# {'status': 'REQUEST_SUCCEEDED',
#  'responseTime': 124,
#  'message': ['Invalid Series for Series LNS12000000'],
#  'Results': {'series': [{'seriesID': ' LNS12000000', 'data': []}]}}

# %%
# Unemployment

headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": [' LNS13000000'],"startyear":"2015", "endyear":"2019"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
        #if 'M01' <= period <= 'M12':'
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(seriesId + '.txt','w')
    output.write (x.get_string())
    output.close()
json_data
# Out:
# {'status': 'REQUEST_SUCCEEDED',
#  'responseTime': 140,
#  'message': ['Invalid Series for Series LNS13000000'],
#  'Results': {'series': [{'seriesID': ' LNS13000000', 'data': []}]}}

# %%
emp_file = "Resources/employment.csv"
emp_df = pd.read_csv(emp_file)
emp_df.head()
# Out:
#      series id     year    period    value
# 0   LNS12000000     2019    M12       158803
# 1   LNS12000000     2019    M11       158536
# 2   LNS12000000     2019    M10       158544
# 3   LNS12000000     2019    M09       158298
# 4   LNS12000000     2019    M08       157895

# %%
unemp_file = "Resources/unemployment.csv"
unemp_df = pd.read_csv(unemp_file)
unemp_df.head()
# Out:
#      series id     year    period    value
# 0   LNS13000000     2019    M12        5753
# 1   LNS13000000     2019    M11        5811
# 2   LNS13000000     2019    M10        5857
# 3   LNS13000000     2019    M09        5753
# 4   LNS13000000     2019    M08        5999

# %%
total_file = "Resources/total.csv"
total_df = pd.read_csv(total_file)
total_df.head()
# Out:
#      series id     year    period    value
# 0   LNS11000000     2019    M12       164556
# 1   LNS11000000     2019    M11       164347
# 2   LNS11000000     2019    M10       164401
# 3   LNS11000000     2019    M09       164051
# 4   LNS11000000     2019    M08       163894

# %%
frame1 = [emp_df,unemp_df,total_df]
result1 = pd.concat(frame1)
result1
# Out:
# C:\Users\Bhoomi\Anaconda3\envs\pythondata\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#       series id     period    value    value     year
# 0    LNS12000000     M12         NaN  158803.0    2019
# 1    LNS12000000     M11         NaN  158536.0    2019
# 2    LNS12000000     M10         NaN  158544.0    2019
# 3    LNS12000000     M09         NaN  158298.0    2019
# 4    LNS12000000     M08         NaN  157895.0    2019
# ..            ...       ...      ...       ...     ...
# 79   LNS13000000     M05         NaN    5938.0    2019
# 80   LNS13000000     M04         NaN    5850.0    2019
# 81   LNS13000000     M03         NaN    6194.0    2019
# 82   LNS13000000     M02         NaN    6181.0    2019
# ...

# %% [markdown]
# ## Zillow API

# %%
zill_url="http://www.zillow.com/webservice/GetRegionChildren.htm?zws-id=X1-ZWz17giky9jf9n_43hp8&state=nj"
response_zill = requests.get(zill_url).content
resp_zill = xmltodict.parse(response_zill)

json.dumps(resp_zill)
regionchildren_df = pd.DataFrame.from_dict(json_normalize(resp_zill), orient='columns')
regionchildren_df.rename(columns=lambda x: x[30:], inplace=True)
regionchildren_df.head(5)

region_list = pd.DataFrame(regionchildren_df['response.list.region'][0])
#dropna and reset index
region_list.dropna(how="any", inplace=True)
region_list.reset_index(drop=True, inplace=True)

region_list["USD"] = [d.get('#text') for d in region_list.zindex]

region_list = region_list.drop(["zindex"], axis=1)
region_list
# Out:
#       id               name   latitude   longitude     USD
# 0    874      Bergen County  40.948055   -74.08323  424000
# 1   2802   Middlesex County  40.430013  -74.416894  293300
# 2   1106      Hudson County  40.732859  -74.075484  321000
# 3   2441    Monmouth County  40.302335  -74.249293  375700
# 4    659       Ocean County  39.823776  -74.259258  255700
# 5    771       Union County  40.665566  -74.300026  304100
# 6    911      Camden County  39.802185  -74.938069  161500
# 7   1964     Passaic County  41.011428  -74.304838  290000
# 8   1241      Morris County  40.867759  -74.578194  418700
# 9   2896  Burlington County  39.862536  -74.724851  212300
# 10  1201      Mercer County    40.2805  -74.712054  224200
# 11  2552    Somerset County  40.566201  -74.599839  382500
# 12  2929  Gloucester County   39.70156  -75.163937  192100
# 13  2133    Atlantic County  39.509238  -74.608641  193300
# 14  2913  Cumberland County  39.312411  -75.148302  132400
# ...

# %% [markdown]
# ## Connect to Postgres

# %%
#connect dataframes to sql
engine = create_engine(f'postgresql://{username}:{password}@localhost:5432/etl_project')
engine.table_names()
new_data_df.to_sql(name='nj_counties', con=engine, if_exists='append', index=False)
region_list.to_sql(name='zillow', con=engine, if_exists='append', index=False)
result1.to_sql(name='employment', con=engine, if_exists='append', index=False)

# %%
pd.read_sql_query('select * from nj_counties', con=engine).head()
# Out:
#    Year                         Area               Industry  \
# 0  2015  Atlantic County, New Jersey  Total, all industries
# 1  2015  Atlantic County, New Jersey  Total, all industries
# 2  2015  Atlantic County, New Jersey  Total, all industries
# 3  2015  Atlantic County, New Jersey  Total, all industries
# 4  2015  Atlantic County, New Jersey  Total, all industries
#
#    Annual Average Establishment Count  Annual Average Employment  \
# 0                                6403                     124905
# 1                                  53                       2580
# 2                                  57                       3556
# 3                                 131                      14773
# 4                                6162                     103996
#
#    Annual Total Wages  Annual Average Weekly Wage  Annual Average Pay  \
# 0          5459761042                         841               43711
# ...

# %%
pd.read_sql_query('select * from zillow', con=engine).head()
# Out:
#      id              name   latitude   longitude     USD
# 0   874     Bergen County  40.948055   -74.08323  424000
# 1  2802  Middlesex County  40.430013  -74.416894  293300
# 2  1106     Hudson County  40.732859  -74.075484  321000
# 3  2441   Monmouth County  40.302335  -74.249293  375700
# 4   659      Ocean County  39.823776  -74.259258  255700

# %%
pd.read_sql_query('select * from employment', con=engine).head()
# Out:
#      series id     period    value    value     year
# 0   LNS12000000     M12         NaN  158803.0    2019
# 1   LNS12000000     M11         NaN  158536.0    2019
# 2   LNS12000000     M10         NaN  158544.0    2019
# 3   LNS12000000     M09         NaN  158298.0    2019
# 4   LNS12000000     M08         NaN  157895.0    2019

# %%
pd.read_sql_query ('select * from zillow a inner join nj_counties b on a.name=b.county', con=engine).head()
# Out:
#      id             name   latitude   longitude     USD  Year  \
# 0  2133  Atlantic County  39.509238  -74.608641  193300  2015
# 1  2133  Atlantic County  39.509238  -74.608641  193300  2015
# 2  2133  Atlantic County  39.509238  -74.608641  193300  2015
# 3  2133  Atlantic County  39.509238  -74.608641  193300  2015
# 4  2133  Atlantic County  39.509238  -74.608641  193300  2015
#
#                           Area               Industry  \
# 0  Atlantic County, New Jersey  Total, all industries
# 1  Atlantic County, New Jersey  Total, all industries
# 2  Atlantic County, New Jersey  Total, all industries
# 3  Atlantic County, New Jersey  Total, all industries
# 4  Atlantic County, New Jersey  Total, all industries
#
#    Annual Average Establishment Count  Annual Average Employment  \
# 0                                6403                     124905
# 1                                  53                       2580
# ...
